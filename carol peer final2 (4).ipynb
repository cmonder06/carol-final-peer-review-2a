# %% [markdown]
# ***CO Final Peer Review***

# %% [markdown]
# **Introduction to Tools for Data Science**

# %% [markdown]
# **Top 12 Data Science Languages**
#
# 1. Python
# 2. R
# 3. SQL
# 4. Java
# 5. Julia
# 6. C
# 7. C++
# 8. JavaScript
# 9. Swift
# 10. Go
# 11. MATLAB
# 12. SAS

# %% [markdown]
# **Top 10 Data Science Libraries**
#
# 1. TensorFlow
# 2. NumPy
# 3. SciPy
# 4. Pandas
# 5. Matplotlib
# 6. Keras
# 7. SciKit-Learn
# 8. PyTorch
# 9. Scrapy
# 10. BeautifulSoup

# %% [markdown]
# **Table of Data Science Tools**
#
# |---Python Data Science Tools---|
# 1. Matplotlib
# 2. Pandas
# 3. NumPy
# 4. Sci-Kit Learn
# 5. Scrapy

# %% [markdown]
# *Introduction to arithmetic expression examples*

# %%
#Evaluating Basic Arithmetic Expression

(40+6)*5
# Out:
# 230

# %%
#This will convert minutes to hours 

def convertMinutestoHours(m1):
    conversion = m1/60
    print ('conversionTotal: ',conversion)

convertMinutestoHours(200)
# Out:
# conversionTotal:  3.3333333333333335

# %% [markdown]
# *Markdown List of Objectives*
#
# - list Title of Notebook
# - create cell for introduction
# - list Data Science Languages
# - LIst Data Science Libraries
# - create a table of Data Science Tools
# - Intoduction cell for Arithmetic Expression Examples
# - list code that multiplies and adds numbers
# - create a code that converts minutes to hours
# - use a cell for author name
# - share notebook to GitHub
# - remember to screen shot first page of notebook

# %% [markdown]
# **AuthorsName**
# **Carol Onderak*
